# %% [markdown]
# # Multivariate Data Sets
#
# ---
# > Erick Eduardo Aguilar Hernández:
# > * mat.ErickAguilar@ciencias.unam.mx
# > * isc.ErickAguilar@gmail.com
#
# ---
#
# #### Data matrix
#
# Suppose that you have n obervations of the random vector $\vec{X}$ (the distribution of the population), such that each vector have p explicative variables. Then the set of observations $\{\vec{X}_i\}_{i=1}^n=\{(X_1,...,X_p)_i\}_{i=1}^n$ can be represented as a matrix called data matrix $\textbf{X}_{n \times p}$, the rows of this matrix represent de index of the observation and each column represent one of the explicative variables.
#
# $$\textbf{X}_{n \times p}=
# \left[ \begin{array}{ccccc}
# x_{1 1} & \cdots & x_{1 j} & \cdots & x_{1 p} \\
# \vdots  & \ddots & \vdots  & \ddots & \vdots \\
# x_{i 1} & \cdots & x_{i j} & \cdots & x_{i p} \\
# \vdots  & \ddots & \vdots  & \ddots & \vdots \\
# x_{n 1} & \cdots & x_{n j} & \cdots & x_{n p} \end{array} \right]
# $$
#
# **Notation:**
# * $\textbf{x}_i$ Indicates the i-th row of $\textbf{X}$, however it will operated as a column.
# * $X_j$ Indicates the j-th column of $\textbf{X}$
#
# **Example 1.1 - 1 [Iris plants]**: The following datset contains samples of 3 iris plants populations of 50 obervations each one. The 3 populations that share the same explicative variables:
# 1. Sepal length in cm
# 2. Sepal width in cm
# 3. Petal length in cm
# 4. Petal width in cm
# 5. Species:
#       - Iris Setosa
#       - Iris Versicolour
#       - Iris Virginica
#
# URL of the dataset.
# https://archive.ics.uci.edu/ml/datasets/iris

# %%
# %matplotlib inline
from IPython.display import display, HTML
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
import numpy as np

pd.set_option('max_colwidth',100)
warnings.filterwarnings('ignore')
plt.style.use('ggplot')

# %%
irisPath = 'DataSets/Iris.csv'
iris_df = pd.read_csv(irisPath)
iris_df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
display(iris_df[iris_df['Species']=='Iris-setosa'][:3])
display(iris_df[iris_df['Species']=='Iris-versicolor'][:3])
display(iris_df[iris_df['Species']=='Iris-virginica'][:3])
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 50            7.0           3.2            4.7           1.4  Iris-versicolor
# 51            6.4           3.2            4.5           1.5  Iris-versicolor
# 52            6.9           3.1            4.9           1.5  Iris-versicolor
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 100            6.3           3.3            6.0           2.5  Iris-virginica
# 101            5.8           2.7            5.1           1.9  Iris-virginica
# 102            7.1           3.0            5.9           2.1  Iris-virginica

# %% [markdown]
# ### Plotting Multivariate Data
#
# **Scatter plots matrix**: A scatter plot matrix arranges all possible two-way scatter plots in a p × p matrix. These displays can be enhanced with brushing, in which individual points or groups of points can be selected in one plot, and be simultaneously highlighted in the other plots.
#
# **Example 1.1 - 2 [Scatter plot matrix of iris plants]**

# %%
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('ggplot')

smp = sns.pairplot(iris_df,hue="Species",diag_kind='kde',palette="plasma")

# %% [markdown]
# # Multivariate descriptive statistics
# ---

# %% [markdown]
# #### Correlation matrix (depende measure)
#
# **Example 1.1 - 3 [Computing multivariate statistics with pandas]**

# %%
features = ['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']
print("Covariance matrix")
display(iris_df[features].cov())
sns.heatmap(iris_df[features].cov(),cmap="Blues", annot=True)
# Out:
# Covariance matrix
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       0.685694     -0.039268       1.273682      0.516904
# SepalWidthCm       -0.039268      0.188004      -0.321713     -0.117981
# PetalLengthCm       1.273682     -0.321713       3.113179      1.296387
# PetalWidthCm        0.516904     -0.117981       1.296387      0.582414
# <Axes: >

# %%
print("Correlation matrix")
display(iris_df[features].corr())
sns.heatmap(iris_df[features].corr(),cmap="Blues", annot=True)
# Out:
# Correlation matrix
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000
# <Axes: >

# %% [markdown]
# **Example 1.1 - 4 [Centering data sets]**
#
# Although matrix expressions help to obtain useful theoretical results, these are too computationally expensive to implement, we rather use methods based on relational algebra in order to obtain descriptive statistics.

# %%
n = len(iris_df)
nn_1 = []
for i in range(0,n):
    nn_1.append([1]*n)
nn_1 = np.matrix(nn_1)
H = np.matrix(np.identity(n))-(1/n)*nn_1
X = np.matrix(iris_df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']].values)
X = np.matrix(iris_df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']].values)
X_centered = np.dot(H,X)
columns = ['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']
centered_iris_df = pd.concat([pd.DataFrame(X_centered,columns=columns),iris_df[['Species']]],axis=1)
centered_iris_df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0        -0.743333         0.446      -2.358667     -0.998667     Iris-setosa
# 1        -0.943333        -0.054      -2.358667     -0.998667     Iris-setosa
# 2        -1.143333         0.146      -2.458667     -0.998667     Iris-setosa
# 3        -1.243333         0.046      -2.258667     -0.998667     Iris-setosa
# 4        -0.843333         0.546      -2.358667     -0.998667     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145       0.856667        -0.054       1.441333      1.101333  Iris-virginica
# 146       0.456667        -0.554       1.241333      0.701333  Iris-virginica
# 147       0.656667        -0.054       1.441333      0.801333  Iris-virginica
# 148       0.356667         0.346       1.641333      1.101333  Iris-virginica
# 149       0.056667        -0.054       1.341333      0.601333  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris_means_df = iris_df[features].mean()
iris_means_df.to_dict()
# Out:
# {'SepalLengthCm': 5.843333333333334,
#  'SepalWidthCm': 3.0540000000000003,
#  'PetalLengthCm': 3.758666666666666,
#  'PetalWidthCm': 1.1986666666666668}

# %%
def getCenteredDataMatrix(data_df,columns,keys):
    data_df = data_df.copy()
    meanVector = data_df[columns].mean().to_dict()
    for col in columns:
        data_df['centered_'+col] = data_df[col]-meanVector[col]
    return data_df[keys+['centered_'+col for col in columns]]

# %%
columns = ['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']
keys = ['Species']
centered_iris_df = getCenteredDataMatrix(iris_df,columns,keys)
centered_iris_df
# Out:
#             Species  centered_SepalLengthCm  centered_SepalWidthCm  \
# 0       Iris-setosa               -0.743333                  0.446
# 1       Iris-setosa               -0.943333                 -0.054
# 2       Iris-setosa               -1.143333                  0.146
# 3       Iris-setosa               -1.243333                  0.046
# 4       Iris-setosa               -0.843333                  0.546
# ..              ...                     ...                    ...
# 145  Iris-virginica                0.856667                 -0.054
# 146  Iris-virginica                0.456667                 -0.554
# 147  Iris-virginica                0.656667                 -0.054
# 148  Iris-virginica                0.356667                  0.346
# 149  Iris-virginica                0.056667                 -0.054
#
#      centered_PetalLengthCm  centered_PetalWidthCm
# 0                 -2.358667              -0.998667
# 1                 -2.358667              -0.998667
# ...

# %% [markdown]
# ### Discriminant power

# %%
plt.figure(figsize=(10,10))
sns.pairplot(centered_iris_df,hue="Species",diag_kind='kde',palette="plasma")

# %%
feature = 'centered_SepalLengthCm'
#feature = 'centered_SepalWidthCm'
#feature = 'centered_PetalLengthCm'
#feature = 'centered_PetalWidthCm'
spec_1='Iris-setosa'
spec_2='Iris-versicolor'
spec_3='Iris-virginica'
plt.figure(figsize=(15,10))
sns.kdeplot(centered_iris_df[centered_iris_df['Species']==spec_1][feature],shade=True,color='purple',label='setosa')
sns.kdeplot(centered_iris_df[centered_iris_df['Species']==spec_2][feature],shade=True,color='red',label='versicolor')
sns.kdeplot(centered_iris_df[centered_iris_df['Species']==spec_3][feature],shade=True,color='orange',label='virginica')
# Out:
# <Axes: xlabel='centered_SepalLengthCm', ylabel='Density'>
